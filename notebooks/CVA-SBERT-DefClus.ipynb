# %% [markdown]
# # Analyzes Def-to-Items cluster similarity within each Source-Definition
#
# - Create group-by of unique Source-Definition-Target with average sim metrics
# -

# %% [markdown]
# # Setup Environment

# %% [markdown]
# ## Set Notebook Parameters

# %%
# use gDrive if you previously saved train_data, etc.
# otherwise, use pre-generated data from repos (Default)
USE_GDRIVE = False

# if using gDrive, then the path to the checkpoint folder must be specified.
# After mounting your gDrive, view /content/drive and "copy path" to FOLDER, like...
CP_PATH = '/content/drive/MyDrive/CVA-SBERT-Analyses/20221119-183356'

# save analysis plots if customized
SAVE_PLOT = False

# %% [markdown]
# ## Import various packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Clone CVA-SBERT GitHub or mount gDrive

# %%
import os.path
from os import path
from time import strftime, localtime
from google.colab import drive

if USE_GDRIVE:
    drive.mount('/content/drive')           # mount gDrive

else:
    # !git clone https://github.com/Hackathorn/CVA-SBERT  # clone repo
    CP_PATH = '/content/CVA-SBERT/data/post_setup_data'
# Out:
# fatal: destination path 'CVA-SBERT' already exists and is not an empty directory.

# %% [markdown]
# ## Read CVA datasets into ```train_data``` dataframe

# %%
train_data = pd.read_csv(CP_PATH+'/train_data.csv')
train_data
# Out:
#        DataId  SourceId  Target  \
# 0           0      2978       1
# 1           1      1056       0
# 2           3      1015       0
# 3           4      2988       0
# 4           7      3130       0
# ...       ...       ...     ...
# 23030   28070     12341       0
# 23031   28071     12822       1
# 23032   28072      3350       1
# 23033   28074      2361       1
# 23034   28075      3093       1
#
#                                               Definition  \
# 0      People whose past behavior is consistent with ...
# 1                      Facilitation from work to school.
# 2             Employees? sense of belongingness at work.
# 3      How attracted members were to the crew and the...
# 4                                Things Manny didn?t do.
# ...                                                  ...
# 23030  The extent to which reputations were observabl...
# 23031  How characteristic each of the attractiveness ...
# 23032  Participants' explanations for why the seller ...
# 23033  Newcomers? belief that good alternative work e...
# 23034  Employees? perceptions of the interpersonal tr...
#
#                                                     Item   Cos_Sim   Euc_Sim
# 0      Have any of your current or previous partners ...  0.183756  1.277688
# 1                I enjoy being a student on this campus.  0.292208  1.189783
# 2      Helps others when it is clear their workload i...  0.322255  1.164255
# 3      Managers rate each crew (low performance/high ...  0.446235  1.052393
# 4       Did Manny tear the book while he was reading it?  0.565577  0.932119
# ...                                                  ...       ...       ...
# 23030  The project required close working relationshi...  0.213506  1.254188
# 23031                                              Wise.  0.147961  1.305403
# 23032                            The buyer is persuasive  0.569600  0.927793
# 23033  To what extent have other co-workers influence...  0.447036  1.051631
# 23034                Employees? suggestions are ignored.  0.443676  1.054822
#
# [23035 rows x 7 columns]

# %%
train_data.sort_values(by = ['SourceId', 'Definition', 'Item', 'Target'])
# Out:
#        DataId  SourceId  Target  \
# 10944   13361       317       1
# 10998   13424       317       1
# 22166   27003       317       1
# 7185     8757       317       1
# 14810   18006       317       1
# ...       ...       ...     ...
# 18434   22448     14046       0
# 9395    11467     14046       1
# 16126   19643     14046       1
# 4980     6079     14046       1
# 19006   23156     14046       1
#
#                                               Definition  \
# 10944  Fits well into a bureaucracy because he has pr...
# 10998  Fits well into a bureaucracy because he has pr...
# 22166  Fits well into a bureaucracy because he has pr...
# 7185   Fits well into a bureaucracy because he has pr...
# 14810  Fits well into a bureaucracy because he has pr...
# ...                                                  ...
# 18434  The emotional experience of anger, frustration...
# 9395   The emotional experience of anger, frustration...
# 16126  The emotional experience of anger, frustration...
# 4980   The extent to which each commitment was fulfil...
# 19006  The extent to which each commitment was fulfil...
#
#                                                     Item   Cos_Sim   Euc_Sim
# 10944                                          Conforms.  0.295002  1.187432
# 10998                              Enjoys detailed work.  0.195786  1.268238
# 22166                    Fits readily into "the system."  0.340720  1.148286
# 7185            Holds back ideas until obviously needed.  0.161294  1.295150
# 14810                               Is a steady plodder.  0.158429  1.297359
# ...                                                  ...       ...       ...
# 18434  Almost all the promises made by my employer du...  0.451701  1.047186
# 9395                I feel betrayed by the organization.  0.361069  1.130426
# 16126  I feel that the organization has violated the ...  0.233476  1.238163
# 4980   Almost all the promises made by my employer du...  0.546662  0.952195
# 19006  So far my employer has done an excellent job o...  0.457458  1.041674
#
# [23035 rows x 7 columns]

# %%
train_data
# Out:
#        DataId  SourceId  Target  \
# 0           0      2978       1
# 1           1      1056       0
# 2           3      1015       0
# 3           4      2988       0
# 4           7      3130       0
# ...       ...       ...     ...
# 23030   28070     12341       0
# 23031   28071     12822       1
# 23032   28072      3350       1
# 23033   28074      2361       1
# 23034   28075      3093       1
#
#                                               Definition  \
# 0      People whose past behavior is consistent with ...
# 1                      Facilitation from work to school.
# 2             Employees? sense of belongingness at work.
# 3      How attracted members were to the crew and the...
# 4                                Things Manny didn?t do.
# ...                                                  ...
# 23030  The extent to which reputations were observabl...
# 23031  How characteristic each of the attractiveness ...
# 23032  Participants' explanations for why the seller ...
# 23033  Newcomers? belief that good alternative work e...
# 23034  Employees? perceptions of the interpersonal tr...
#
#                                                     Item   Cos_Sim   Euc_Sim
# 0      Have any of your current or previous partners ...  0.183756  1.277688
# 1                I enjoy being a student on this campus.  0.292208  1.189783
# 2      Helps others when it is clear their workload i...  0.322255  1.164255
# 3      Managers rate each crew (low performance/high ...  0.446235  1.052393
# 4       Did Manny tear the book while he was reading it?  0.565577  0.932119
# ...                                                  ...       ...       ...
# 23030  The project required close working relationshi...  0.213506  1.254188
# 23031                                              Wise.  0.147961  1.305403
# 23032                            The buyer is persuasive  0.569600  0.927793
# 23033  To what extent have other co-workers influence...  0.447036  1.051631
# 23034                Employees? suggestions are ignored.  0.443676  1.054822
#
# [23035 rows x 7 columns]

# %% [markdown]
# RESULTS...
# - DataId should match with original CSV dataset rows   # TODO - check!
# - TODO - more comments on above

# %% [markdown]
# # Find mean Cos_Sim for Items by Source-Definition-Target
#
# - Group Items by Source-Definition-Target
# - Calculate mean Cos_Sim for Target = 0/1

# %%
# DefItem_clusters = train_data.groupby(['SourceId', 'Definition', 'Target', 'Item'])['Cos_Sim'].count()
DefItem_clusters = train_data.groupby(['SourceId', 'Definition', 'Target'])['Item'].count()
DefItem_clusters
# Out:
# SourceId  Definition                                                                                     Target
# 317       Fits well into a bureaucracy because he has proper respect for authority and rules.            1         18
#           Precise, reliable, and disciplined.                                                            1         18
# 353       The first people to adopt the new technology.                                                  1          1
# 354       A result of hands-on experience gained during training.                                        0          9
#                                                                                                          1          4
#                                                                                                                    ..
# 14032     We measured manager's voice to their supervisor using the manager's general manager.           0          3
#                                                                                                          1          3
# 14046     The emotional experience of anger, frustration, and betrayal associated with broken promises.  0          1
#                                                                                                          1          2
#           The extent to which each commitment was fulfilled by their employer.                           1          2
# Name: Item, Length: 4218, dtype: int64

# %%
DefItem_clusters = train_data.groupby(['SourceId', 'Definition', 'Target'], as_index=False)['Cos_Sim', 'Euc_Sim'].mean()
DefItem_clusters
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#       SourceId                                         Definition  Target  \
# 0          317  Fits well into a bureaucracy because he has pr...       1
# 1          317                Precise, reliable, and disciplined.       1
# 2          353      The first people to adopt the new technology.       1
# 3          354  A result of hands-on experience gained during ...       0
# 4          354  A result of hands-on experience gained during ...       1
# ...        ...                                                ...     ...
# 4213     14032  We measured manager's voice to their superviso...       0
# 4214     14032  We measured manager's voice to their superviso...       1
# 4215     14046  The emotional experience of anger, frustration...       0
# 4216     14046  The emotional experience of anger, frustration...       1
# 4217     14046  The extent to which each commitment was fulfil...       1
#
#        Cos_Sim   Euc_Sim
# 0     0.260213  1.212985
# 1     0.312180  1.170302
# 2     0.288779  1.192662
# 3     0.166185  1.290405
# 4     0.061682  1.367960
# ...        ...       ...
# 4213  0.226383  1.238673
# 4214  0.113301  1.329695
# 4215  0.451701  1.047186
# 4216  0.297272  1.184294
# 4217  0.502060  0.996934
#
# [4218 rows x 5 columns]

# %% [markdown]
# RESULTS....
# - Ignore Euc_Sim b/c high coorelated with Cos_Sim

# %% [markdown]
# Plot histogram of each DefItem_cluster split by Target 0/1

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")
f, axs = plt.subplots(1, 2, figsize=(20, 10))
# sns.despine(f)    # eliminate top & right border

sns.histplot(
    DefItem_clusters,
    x="Cos_Sim", hue="Target",
    kde=True, 
    multiple="layer",   # layer, dodge, stack, fill
    palette="copper",    # Blues, light:m_r, copper, flare
    edgecolor=".3",
    linewidth=.5,
    log_scale=False,
    ax=axs[0],
)
# axs[0].set_yscale("log")
sns.histplot(
    DefItem_clusters,
    x="Cos_Sim", hue="Target",
    kde=True, 
    multiple="fill",    # layer, dodge, stack, fill
    palette="Blues",    # Blues, light:m_r, copper, flare
    edgecolor=".3",
    linewidth=.5,
    log_scale=False,
    ax=axs[1],
)

# %% [markdown]
# RESULTS...
# - Same as distributions of individual Items, as shown in SimDim notebook
# - Wonder if Sources for Sim > 0.6 & Target=1 were consistently high scoring
# - Likewise, Sources for Sim < 0.1 & Target=1 were low scoring

# %% [markdown]
# ## Find average Cos_Sim by just Source for Target = 1

# %%
# Ignore Target = 0 DefItem_clusters
df = DefItem_clusters.loc[DefItem_clusters['Target'] == 1]

# groupby SourceId & calculate mean Cos_Sim
df = df.groupby(['SourceId'], as_index=False)['Cos_Sim'].mean()


# DefItem_clusters = train_data.groupby(['SourceId', 'Definition', 'Target'], as_index=False)['Cos_Sim', 'Euc_Sim'].mean()


df
# Out:
#      SourceId   Cos_Sim
# 0         317  0.286196
# 1         353  0.288779
# 2         354  0.170132
# 3         417  0.237644
# 4         875  0.468755
# ..        ...       ...
# 662     14020  0.382236
# 663     14023  0.263655
# 664     14027  0.437796
# 665     14032  0.281899
# 666     14046  0.399666
#
# [667 rows x 2 columns]

# %% [markdown]
# RESULTS...
# - Some insights........
